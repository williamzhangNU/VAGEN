# %%
from vagen.env.manipulation.maniskill.env.utils import build_env,handel_info
import  vagen.env.manipulation.maniskill.env

# %%
env_ids=["AlignTwoCube","PutAppleInDrawer","StackThreeCube","PlaceTwoCube"]

# %%
env=build_env(env_ids[0])
# Out:
# 2025-04-18 04:25:42,575 - mani_skill  - WARNING - No initial pose set for articulation builder of panda, setting to default pose q=[1,0,0,0], p=[0,0,0]. There may be simulation issues/bugs if this articulation at it's initial pose collides with other objects at their initial poses.
# 2025-04-18 04:25:42,686 - mani_skill  - WARNING - No initial pose set for actor builder of red_cube, setting to default pose q=[1,0,0,0], p=[0,0,0]. Not setting reasonable initial poses may slow down simulation, see https://github.com/haosulab/ManiSkill/issues/421.
# 2025-04-18 04:25:42,687 - mani_skill  - WARNING - No initial pose set for actor builder of green_cube, setting to default pose q=[1,0,0,0], p=[0,0,0]. Not setting reasonable initial poses may slow down simulation, see https://github.com/haosulab/ManiSkill/issues/421.
# ...

# %%
obs,info = env.reset()
processed_info=handel_info(info)

# %%
for k,v in processed_info.items():
    print(k,v)
# Out:
# obj_positions {'red_cube_pos': array([76, 56, 20]), 'green_cube_pos': array([  16, -116,   20])}
# other_info {'is_red_cube_grasped': False, 'is_red_cube_at_x0': False, 'is_green_cube_grasped': False, 'is_green_cube_at_x0': False, 'stage_0_success': False, 'stage_1_success': False, 'success': False, 'skill_success': False}

# %%
img=env.render()
# show img
import matplotlib.pyplot as plt
plt.imshow(img)
