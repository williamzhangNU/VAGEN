# %%
import pandas as pd
pd.set_option("display.max_colwidth", None)
# 指定数据路径
train_path = "/workspace/VAGEN/data/mental-rotation/train.parquet"
test_path = "/workspace/VAGEN/data/mental-rotation/test.parquet"

# 读取 parquet 文件
train_df = pd.read_parquet(train_path)
test_df = pd.read_parquet(test_path)

# 查看基本信息
print("=== Train Dataset Info ===")
print(train_df.info())
print("\nSample rows from train dataset:")
display(train_df.head())

print("\n=== Test Dataset Info ===")
print(test_df.info())
print("\nSample rows from test dataset:")
display(test_df.head())
# Out:
# === Train Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   data_source  100 non-null    object
#  1   prompt       100 non-null    object
#  2   extra_info   100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB
# None
#
# Sample rows from train dataset:
#        data_source                             prompt  \
# 0  mental-rotation  [{'content': '', 'role': 'user'}]
# 1  mental-rotation  [{'content': '', 'role': 'user'}]
# 2  mental-rotation  [{'content': '', 'role': 'user'}]
# 3  mental-rotation  [{'content': '', 'role': 'user'}]
# 4  mental-rotation  [{'content': '', 'role': 'user'}]
#
#                                                                                                                                                              extra_info
# 0  {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 12623, 'split': 'train'}
# 1  {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 13781, 'split': 'train'}
# 2   {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 1326, 'split': 'train'}
# 3   {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 8484, 'split': 'train'}
# 4  {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 16753, 'split': 'train'}
# === Test Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   data_source  20 non-null     object
#  1   prompt       20 non-null     object
#  2   extra_info   20 non-null     object
# dtypes: object(3)
# memory usage: 612.0+ bytes
# None
#
# Sample rows from test dataset:
#        data_source                             prompt  \
# 0  mental-rotation  [{'content': '', 'role': 'user'}]
# 1  mental-rotation  [{'content': '', 'role': 'user'}]
# 2  mental-rotation  [{'content': '', 'role': 'user'}]
# 3  mental-rotation  [{'content': '', 'role': 'user'}]
# 4  mental-rotation  [{'content': '', 'role': 'user'}]
#
#                                                                                                                                                             extra_info
# 0  {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 12623, 'split': 'test'}
# 1  {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 13781, 'split': 'test'}
# 2   {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 1326, 'split': 'test'}
# 3   {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 8484, 'split': 'test'}
# 4  {'env_config': {'device': 'cpu', 'max_steps': 5, 'render_mode': 'vision', 'rotate_granularity': 90}, 'env_name': 'mental-rotation', 'seed': 16753, 'split': 'test'}
